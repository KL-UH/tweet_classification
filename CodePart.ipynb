# %%
import pandas as pd

# %%
project = pd.read_csv('dataset.csv',encoding = ('ISO-8859-1'),low_memory = False)
#multiple datatypes in column results in error so intially  low_memory = true means csv file get splits and guesses the dtypes but it will show error as it is not same so low_memory will read all file and confirms dtypes

# %%
project.head()
# Out:
#    0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY _TheSpecialOne_  \
# 0  0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY   scotthamilton
# 1  0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY        mattycus
# 2  0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY         ElleCTF
# 3  0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY          Karoli
# 4  0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY        joy_wolf
#
#   @switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D
# 0  is upset that he can't update his Facebook by ...
# 1  @Kenichan I dived many times for the ball. Man...
# 2    my whole body feels itchy and like its on fire
# 3  @nationwideclass no, it's not behaving at all....
# 4                      @Kwesidei not the whole crew

# %%
project.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599999 entries, 0 to 1599998
# Data columns (total 6 columns):
#  #   Column                                                                                                               Non-Null Count    Dtype
# ---  ------                                                                                                               --------------    -----
#  0   0                                                                                                                    1599999 non-null  int64
#  1   1467810369                                                                                                           1599999 non-null  int64
#  2   Mon Apr 06 22:19:45 PDT 2009                                                                                         1599999 non-null  object
# ...

# %%
#It is very useful for fundamental scientific computations in Machine Learning(matrices,arrays)

# %%
import numpy as np

# %%
#for plotting library

# %%
import matplotlib.pyplot as plt

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
pip install neattext
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import neattext.functions as nfx

# %%
project.shape
# Out:
# (1599999, 6)

# %%
project = pd.read_csv('dataset.csv',encoding='latin1',header=None)

# %%
project.head()
# Out:
#    0           1                             2         3                4  \
# 0  0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY  _TheSpecialOne_
# 1  0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY    scotthamilton
# 2  0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY         mattycus
# 3  0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY          ElleCTF
# 4  0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY           Karoli
#
#                                                    5
# 0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1  is upset that he can't update his Facebook by ...
# 2  @Kenichan I dived many times for the ball. Man...
# 3    my whole body feels itchy and like its on fire
# 4  @nationwideclass no, it's not behaving at all....

# %%
project.columns = ['emotion', 'id', 'date', 'query', 'user_id', 'text']
project.head()
# Out:
#    emotion          id                          date     query  \
# 0        0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1        0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2        0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3        0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4        0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
#
#            user_id                                               text
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....

# %%
project = project.drop(['id', 'date', 'query', 'user_id'], axis=1)
# refers to vertical axis or columns

# %%
project.head()
# Out:
#    emotion                                               text
# 0        0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1        0  is upset that he can't update his Facebook by ...
# 2        0  @Kenichan I dived many times for the ball. Man...
# 3        0    my whole body feels itchy and like its on fire
# 4        0  @nationwideclass no, it's not behaving at all....

# %%
project['emotion'].value_counts()
# Out:
# 0    800000
# 4    800000
# Name: emotion, dtype: int64

# %%
lab_to_sentiment = {0:"Negative", 4:"Positive"}
def label_decoder(label):
  return lab_to_sentiment[label]
project.emotion = project.emotion.apply(lambda x: label_decoder(x))
project.head()
# Out:
#     emotion                                               text
# 0  Negative  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1  Negative  is upset that he can't update his Facebook by ...
# 2  Negative  @Kenichan I dived many times for the ball. Man...
# 3  Negative    my whole body feels itchy and like its on fire
# 4  Negative  @nationwideclass no, it's not behaving at all....

# %%
#null values checking
project.isnull().sum()
# Out:
# emotion    0
# text       0
# dtype: int64

# %%
project['emotion'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
pip install textblob
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from textblob import TextBlob

# %%
def get_sentiment(text):
    blob = TextBlob(text)
    sentiment = blob.sentiment.polarity 
    if sentiment>0:
        result = "Positive"
    elif sentiment < 0 :
        result = "Negative"
    else:
        result = "Neutral"
    return result

# %%
get_sentiment("I do not like this example at all, it is too boring")
# Out:
# 'Negative'

# %%
dir(nfx)
# Out:
# ['BTC_ADDRESS_REGEX',
#  'CURRENCY_REGEX',
#  'CURRENCY_SYMB_REGEX',
#  'Counter',
#  'DATE_REGEX',
#  'EMAIL_REGEX',
#  'EMOJI_REGEX',
#  'HASTAG_REGEX',
#  'MASTERCard_REGEX',
#  'MD5_SHA_REGEX',
#  'MOST_COMMON_PUNCT_REGEX',
#  'NUMBERS_REGEX',
#  'PHONE_REGEX',
#  'PoBOX_REGEX',
#  'SPECIAL_CHARACTERS_REGEX',
#  'STOPWORDS',
#  'STOPWORDS_de',
#  'STOPWORDS_en',
#  'STOPWORDS_es',
#  'STOPWORDS_fr',
#  'STOPWORDS_ru',
#  'STOPWORDS_yo',
#  'STREET_ADDRESS_REGEX',
#  'TextFrame',
#  'URL_PATTERN',
#  'USER_HANDLES_REGEX',
#  'VISACard_REGEX',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__generate_text',
#  '__loader__',
#  '__name__',
#  '__numbers_dict',
#  '__package__',
#  '__spec__',
#  '_lex_richness_herdan',
#  '_lex_richness_maas_ttr',
#  'clean_text',
#  'defaultdict',
#  'digit2words',
#  'extract_btc_address',
#  'extract_currencies',
#  'extract_currency_symbols',
#  'extract_dates',
#  'extract_emails',
#  'extract_emojis',
# ...

# %%
project['Clean_Text'] = project['text'].apply(nfx.remove_stopwords)

# %%
project['Clean_Text'] = project['Clean_Text'].apply(nfx.remove_userhandles)

# %%
project['Clean_Text'] = project['Clean_Text'].apply(nfx.remove_punctuations)

# %%
project['Clean_Text'] = project['Clean_Text'].apply(nfx.remove_dates)

# %%
project['Clean_Text'] = project['Clean_Text'].apply(nfx.remove_phone_numbers)

# %%
project['Clean_Text'] = project['Clean_Text'].apply(nfx.remove_urls)

# %%
project[['text','Clean_Text']]
# Out:
#                                                       text  \
# 0        @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1        is upset that he can't update his Facebook by ...
# 2        @Kenichan I dived many times for the ball. Man...
# 3          my whole body feels itchy and like its on fire
# 4        @nationwideclass no, it's not behaving at all....
# ...                                                    ...
# 1599995  Just woke up. Having no school is the best fee...
# 1599996  TheWDB.com - Very cool to hear old Walt interv...
# 1599997  Are you ready for your MoJo Makeover? Ask me f...
# 1599998  Happy 38th Birthday to my boo of alll time!!! ...
# 1599999  happy #charitytuesday @theNSPCC @SparksCharity...
#
#                                                 Clean_Text
# 0          http://twitpiccom/2y1zl  Awww thats bummer s...
# 1        upset cant update Facebook texting it cry resu...
# 2            dived times ball Managed save 50% rest bounds
# ...

# %%
pip install collections
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement collections (from versions: none)
# ERROR: No matching distribution found for collections

# %%
from collections import Counter

# %%
def extract_keywords(text,num = 50):
    tokens = [ tok for tok in text.split()]
    most_common_tokens = Counter(tokens).most_common(num)
    return dict(most_common_tokens)

# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
emotion_list = project['emotion'].unique().tolist()

# %%
emotion_list
# Out:
# ['Negative', 'Positive']

# %%
neg_list = project[project['emotion'] == 'Negative']['Clean_Text'].tolist()

# %%
neg_docx = ' '.join(neg_list)

# %%
keyword_Negative = extract_keywords(neg_docx)

# %%
keyword_Negative
# Out:
# {'Im': 61977,
#  'work': 41948,
#  'like': 39574,
#  'im': 39195,
#  'cant': 38027,
#  'day': 35506,
#  'today': 34084,
#  'going': 29701,
#  'got': 29624,
#  'miss': 28527,
#  'want': 28451,
#  'know': 25252,
#  'time': 24877,
#  'good': 24656,
#  'sad': 24187,
#  'home': 22432,
#  '2': 21479,
#  'think': 20792,
#  'feel': 20788,
#  'u': 20554,
#  'need': 19949,
#  'bad': 19694,
#  'wish': 18570,
#  'amp': 18417,
#  'night': 18064,
#  'tomorrow': 17604,
#  'it': 17258,
#  'sleep': 17210,
#  'me': 16440,
#  'lol': 15506,
#  'hate': 15356,
#  'sorry': 14962,
#  'love': 14140,
#  'right': 14064,
#  'now': 13805,
#  'new': 13511,
#  'sick': 13428,
#  'tonight': 12249,
#  'dont': 12212,
#  'gonna': 11929,
#  'come': 11725,
#  'getting': 11704,
#  'oh': 11531,
#  'bed': 11502,
#  'hope': 11482,
#  'week': 11445,
#  'morning': 11445,
#  'school': 11422,
#  'wanna': 11254,
#  'way': 10994}

# %%
def plot_most_common_words(mydict):
    df_01 = pd.DataFrame(mydict.items(),columns = ['token','count'])
    plt.figure(figsize=(20,10))
    sns.barplot(x = 'token',y='count',data = df_01)
    plt.xticks(rotation=45)
    plt.show()

# %%
plot_most_common_words(keyword_Negative)

# %%
pos_list = project[project['emotion'] == 'Positive']['Clean_Text'].tolist()

# %%
pos_docx = ' '.join(pos_list)

# %%
keyword_Positive = extract_keywords(pos_docx)

# %%
keyword_Positive
# Out:
# {'Im': 47600,
#  'good': 46235,
#  'day': 40151,
#  'love': 38540,
#  'like': 35693,
#  'u': 26828,
#  'time': 26484,
#  'im': 26094,
#  'today': 25886,
#  'going': 25268,
#  'know': 24600,
#  'got': 24494,
#  'new': 22589,
#  'amp': 21921,
#  'great': 20995,
#  'lol': 20919,
#  'it': 20776,
#  'night': 19649,
#  'you': 19409,
#  'think': 18494,
#  'thanks': 18103,
#  'work': 17892,
#  'fun': 16833,
#  'haha': 15910,
#  '2': 15645,
#  'morning': 15404,
#  'Thanks': 15139,
#  'cant': 14529,
#  'home': 14036,
#  'nice': 13832,
#  'Good': 13475,
#  'tomorrow': 13301,
#  'wait': 13167,
#  'hope': 12958,
#  'happy': 12958,
#  'me': 12500,
#  'need': 12323,
#  'thats': 12259,
#  'twitter': 12035,
#  'want': 11742,
#  'better': 11642,
#  'way': 11626,
#  'Ill': 11550,
#  'now': 11499,
#  'awesome': 11444,
#  'right': 11410,
#  'tonight': 11192,
#  'too': 10483,
#  'watching': 10442,
#  'come': 10394}

# %%
plot_most_common_words(keyword_Positive)

# %%
from wordcloud import WordCloud
def plot_wordcloud(docx):
    mywordcloud = WordCloud().generate(docx)
    plt.figure(figsize = (20,20))
    plt.imshow(mywordcloud , interpolation = 'bilinear')
    plt.axis('off')
    plt.show()

# %%
plot_wordcloud(neg_docx)

# %%
plot_wordcloud(pos_docx)

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # ML

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,plot_confusion_matrix

# %%
from sklearn.model_selection import train_test_split

# %%
Xfeatures = project['Clean_Text']
ylabels = project['emotion']

# %%
Xfeatures
#convert into vectors
# Out:
# 0            http://twitpiccom/2y1zl  Awww thats bummer s...
# 1          upset cant update Facebook texting it cry resu...
# 2              dived times ball Managed save 50% rest bounds
# 3                                 body feels itchy like fire
# 4                     no behaving all im mad here cant there
#                                  ...
# 1599995                          woke up school best feeling
# 1599996    TheWDBcom  cool hear old Walt interviews â« h...
# 1599997                      ready MoJo Makeover Ask details
# 1599998    Happy 38th Birthday boo alll time Tupac Amaru ...
# 1599999                          happy #charitytuesday
# Name: Clean_Text, Length: 1600000, dtype: object

# %%
cv = CountVectorizer()
X = cv.fit_transform(Xfeatures)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,ylabels,test_size=0.3,random_state = 30)

# %%
nv_model = MultinomialNB()
nv_model.fit(X_train,y_train)
# Out:
# MultinomialNB()

# %%
nv_model.score(X_test,y_test)
# Out:
# 0.7662020833333333

# %%
#Predictions of y with x using nb
y_pred_for_nv = nv_model.predict(X_test)

# %%
y_pred_for_nv
# Out:
# array(['Positive', 'Positive', 'Negative', ..., 'Negative', 'Negative',
#        'Positive'], dtype='<U8')

# %%
sample_text = ["This was a helpful example but I would prefer another one"]

# %%
vect = cv.transform(sample_text).toarray()

# %%
# Make Prediction
nv_model.predict(vect)
# Out:
# array(['Positive'], dtype='<U8')

# %%
# Check For the Prediction Probability
nv_model.predict_proba(vect)
# Out:
# array([[0.1324549, 0.8675451]])

# %%
# Get all class for our model
nv_model.classes_
# Out:
# array(['Negative', 'Positive'], dtype='<U8')

# %%
np.max(nv_model.predict_proba(vect))
# Out:
# 0.8675450951283791

# %%
def predict_emotion(sample_text,model):
    myvect =  cv.transform(sample_text).toarray()
    prediction = model.predict(myvect)
    pred_proba = model.predict_proba(myvect)
    pred_percentage_for_all = dict(zip(model.classes_,pred_proba))
    print("Prediction:{}, Prediction Score:{}".format(prediction[0],np.max(pred_proba)))

# %%
predict_emotion(sample_text,nv_model)
# Out:
# Prediction:Positive, Prediction Score:0.8675450951283791

# %% [markdown]
# # PREDICTION - NB Model

# %%
predict_emotion(["This was a helpful example but I would prefer another one"],nv_model)
# Out:
# Prediction:Positive, Prediction Score:0.8675450951283791

# %%
# Classification
print(classification_report(y_test,y_pred_for_nv))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.76      0.78      0.77    240610
#     Positive       0.77      0.75      0.76    239390
#
#     accuracy                           0.77    480000
#    macro avg       0.77      0.77      0.77    480000
# weighted avg       0.77      0.77      0.77    480000

# %%
# Confusion
confusion_matrix(y_test,y_pred_for_nv)
# Out:
# array([[187100,  53510],
#        [ 58713, 180677]], dtype=int64)

# %%
# Plot Confusion Matrix
plot_confusion_matrix(nv_model,X_test,y_test)
# Out:
# C:\Users\DEEPTHI\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# # Logistic Regression Model

# %%
# LogisticRegression
lr_model = LogisticRegression()
lr_model.fit(X_train,y_train)
# Out:
# C:\Users\DEEPTHI\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
#Accuracy
lr_model.score(X_test,y_test)
# Out:
# 0.7743854166666667

# %%
# Single Predict
predict_emotion(sample_text,lr_model)
# Out:
# Prediction:Positive, Prediction Score:0.7843011800238541

# %%
y_pred_for_lr = lr_model.predict(X_test)

# %%
print(classification_report(y_test,y_pred_for_lr))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.79      0.74      0.77    240610
#     Positive       0.76      0.80      0.78    239390
#
#     accuracy                           0.77    480000
#    macro avg       0.78      0.77      0.77    480000
# weighted avg       0.78      0.77      0.77    480000

# %%
plot_confusion_matrix(nv_model,X_test,y_test)
# Out:
# C:\Users\DEEPTHI\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %%
import joblib

# %%
from sklearn import svm

# %%
svm_model = svm.SVC(kernel='linear')

# %%
svm_model.fit(X_train,y_train)

# %%
svm_model.score(X_test,y_test)

# %%
predict_emotion(sample_text,svm_model)

# %%
y_pred_for_svm = svm_model.predict(X_test)

# %%
print(classification_report(y_test,y_pred_for_svm))

# %%
plot_confusion_matrix(svm_model,X_test,y_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_model = KNeighborsClassifier(n_neighbors=2)

# %%
knn_model.fit(X_train,y_train)

# %%
knn_model.score(X_test,y_test)

# %%
predict_emotion(sample_text,knn_model)

# %%
y_pred_for_knn = knn_model.predict(X_test)

# %%
print(classification_report(y_test,y_pred_for_knn))

# %%
plot_confusion_matrix(knn_model,X_test,y_test)
